# %% [markdown]
# ### This notebook perfoms the following tasks:
# ##### 1) read Historical-Settlement-Reports.zip from DATA.GOV.AU
# ##### 2) ingest a selected report into pandas dataframe ("Local Government Area of Permanent Settlers (All Streams) with a Date of Settlement* between 01 January 2016 and 31 December 2016" in this example)
# ##### 3) GeoCode LGA with lat,long using Google Maps Geocoding API. Note you will need to use your own Google API key

# %%
import requests, zipfile, io
import pandas as pd
import re

# %%
api_key = 'put your Google Maps Geocoding API key here'

# %%
#get ZIP archive with Historical-Settlement-Reports from DATA.GOV.AU
read_zip = requests.get('https://data.gov.au/dataset/8d1b90a9-a4d7-4b10-ad6a-8273722c8628/resource/27adc111-5296-4dc4-884f-3cfbc33b02f3/download/historical-settlement-reports.zip')

# %%
archive = zipfile.ZipFile(io.BytesIO(read_zip.content))

# %%
def list_all_elements_of_a_list(list_name):
    for i in range (0,len(list_name)):
        print(i,":",list_name[i])

# %%
#archive.namelist() lists all files in archive.
#the code below lists all files together with list element index

list_all_elements_of_a_list(archive.namelist())
# Out:
# 0 : statebymigrationstreamoct09tosep14.pdf
# 1 : agebymigrationstreamjan10todec14.docx
# 2 : agebymigrationstreamjan10todec14.pdf
# 3 : agebymigrationstreammarch2010toapril2015.docx
# 4 : agebymigrationstreammarch2010toapril2015.pdf
# 5 : agebymigrationstreamoct09tosep14.docx
# 6 : agebymigrationstreamoct09tosep14.pdf
# 7 : countryofbirthbymigrationstreamapril2010tomarch2015.docx
# 8 : countryofbirthbymigrationstreamapril2010tomarch2015.pdf
# 9 : countryofbirthbymigrationstreamjan10todec14.docx
# 10 : countryofbirthbymigrationstreamjan10todec14.pdf
# 11 : countryofbirthbymigrationstreamoct09tosep14.docx
# 12 : countryofbirthbymigrationstreamoct09tosep14.pdf
# 13 : ethnicitybymigrationstreamapril2010tomarch2015.docx
# 14 : ethnicitybymigrationstreamapril2010tomarch2015.pdf
# 15 : ethnicitybymigrationstreamjan10todec14.docx
# 16 : ethnicitybymigrationstreamjan10todec14.pdf
# 17 : ethnicitybymigrationstreamoct09tosep14.docx
# 18 : ethnicitybymigrationstreamoct09tosep14.pdf
# 19 : genderbymigrationstreamapril2010tomarch2015.docx
# 20 : genderbymigrationstreamapril2010tomarch2015.pdf
# 21 : genderbymigrationstreamjan10todec14.docx
# 22 : genderbymigrationstreamjan10todec14.pdf
# 23 : genderbymigrationstreamoct09tosep14.docx
# 24 : genderbymigrationstreamoct09tosep14.pdf
# 25 : languagebymigrationstreamapril2010tomarch2015.docx
# 26 : languagebymigrationstreamapril2010tomarch2015.pdf
# 27 : languagebymigrationstreamjan10todec14.docx
# 28 : languagebymigrationstreamjan10todec14.pdf
# 29 : languagebymigrationstreamoct09tosep14.docx
# 30 : languagebymigrationstreamoct09tosep14.pdf
# 31 : localgovernmentareabymigrationstreamoct09tosep14.docx
# 79 : Language by Migration Stream - 1 October 2015 to 4 October 2016..docx
# 80 : Language by Migration Stream - 1 October 2015 to 4 October 2016..xlsx
# 81 : Local Government Area by Migration Stream - 1 October 2015 to 4 October 2016.csv
# 82 : Local Government Area by Migration Stream - 1 October 2015 to 4 October 2016.docx
# 83 : Local Government Area by Migration Stream - 1 October 2015 to 4 October 2016.xlsx
# 84 : Religion by Migration Stream - 1 October 2015 to 4 October 2016.csv
# 85 : Religion by Migration Stream - 1 October 2015 to 4 October 2016.docx
# 86 : Religion by Migration Stream - 1 October 2015 to 4 October 2016.xlsx
# 87 : State by Migration Stream - 1 October 2015 to 4 October 2016.csv
# 88 : State by Migration Stream - 1 October 2015 to 4 October 2016.docx
# 89 : State by Migration Stream - 1 October 2015 to 4 October 2016.xlsx
# 90 : Settlement Data Reports January to December 2016.docx
# 91 : Settlement Data Reports January to December 2016.xlsx
# 92 : Settlement Data Reports January to March 2017.xlsx
# 93 : Settlement Data Reports January to March 2017.docx
# 94 : Settlement Data Reports January 2017 to 30 June 2017.docx
# 95 : Settlement Data Reports January 2017 to 30 June 2017.xlsx
# 96 : Settlement Data Reports July 2016 to 30 June 2017.docx
# 97 : Settlement Data Reports July 2016 to 30 June 2017.xlsx

# %%
#choose the file to read from the archive
i=91

# %%
file=archive.extract(archive.namelist()[i])
file
# Out:
# '/Users/alexanderfetisov/Documents/Savvi/ipynb/Settlement Data Reports January to December 2016.xlsx'

# %%
#read the file into dataframe
report = pd.ExcelFile(file)

# %%
#list all sheets of the excel file
list_all_elements_of_a_list(report.sheet_names)
# Out:
# 0 : Caveats
# 1 : Settlement Date
# 2 : Age Group
# 3 : Country of Birth
# 4 : Current States
# 5 : Ethnicity
# 6 : Gender
# 7 : Local Government Area
# 8 : Main Language
# 9 : Religion

# %%
# read a specific sheet to DataFrame
sheet_id = 7

#skip the first 11 rows in the Excel sheet
skip_rows = 11 

#skip the first 11 rows in the Excel sheet
read_columns = [0,1,2,3,4,5]

# %%
#ingest sheet into dataframe
lga = report.parse(report.sheet_names[sheet_id], skiprows=skip_rows, usecols=read_columns, skip_footer=1)

# %%
#replace spaces in columns' header with _
lga.columns = lga.columns.str.replace('\s+', '_')

# %%
#Extract exact LGA name. Also convert 'Unincorporated <state>' into <state>.

def get_state(lga_name):
    state_name =  re.search('^.*(?=(\s\())', lga_name)
    unincorp_name =  re.search('Unincorporated', lga_name)
    
    # If state_name exists, extract and return it.
    if state_name:
        return state_name.group()
    # If lga_name conctains "Unicorporated", extract and return only State name.
    elif unincorp_name:
        return re.search('[^ ]* (.*)', lga_name).group(1)
    # in all other cases return original value
    else:
        return lga_name

# %%
lga['LGA'] = lga['Local_Government_Area'].apply(get_state)

# %%
lga
# Out:
#          Local_Government_Area  Humanitarian  Family  Skilled  Grand_Total  \
# 2      0.025369             Fairfield
# 3      0.020857            Parramatta
# 4      0.020292             Melbourne
# 5      0.020227                Sydney
# 6      0.016867                  Hume
# 7      0.016604               Wyndham
# 8      0.016413     Greater Dandenong
# 9      0.015921                   ACT
# 10     0.015761             Blacktown
# 11     0.014609                Monash
# 12     0.014212            Gold Coast
# 13     0.013640              Stirling
# 14     0.012908            Canterbury
# 15     0.012892                 Casey
# 16     0.012385              Moreland
# 17     0.012160            Whitehorse
# 18     0.011721             Liverpool
# 19     0.011683            Whittlesea
# 20     0.011489               Canning
# 21     0.011309                Auburn
# 22     0.011187                  Ryde
# 23     0.010913              Rockdale
# 24     0.010814               Holroyd
# 25     0.010585              Randwick
# 26     0.010524              Brimbank
# 27     0.010398            Hurstville
# 28     0.009727             Glen Eira
# 29     0.009566             Bankstown
# ..          ...                   ...
# 475    0.000000           Boyup Brook
# 476    0.000000             Cranbrook
# 477    0.000000            Mukinbudin
# 478    0.000000             Perenjori
# 479    0.000000                  Kent
# 480    0.000000  Lower Eyre Peninsula
# 481    0.000000               Mullewa
# 482    0.000000                Morawa
# 483    0.000000               Bombala
# 484    0.000000                Bulloo
# 485    0.000000             Tumby Bay
# 486    0.000000                Barcoo
# 487    0.000000                Dorset
# 488    0.000000                Coorow
# 489    0.000000              Wickepin
# 490    0.000000                 Cleve
# 491    0.000000              Pingelly
# 492    0.000000          Barunga West
# 493    0.000000  Karoonda East Murray
# 494    0.000000              Nungarin
# 495    0.000000              McKinlay
# 496    0.000000              Richmond
# 497    0.000000          Peterborough
# 498    0.000000            Bruce Rock
# 499    0.000000            Tumbarumba
# 500    0.000000                Boulia
# 501    0.000000               Dowerin
# 502    0.000000           Wyalkatchem
# 503    0.000000                Wiluna
# 504    0.000000        Mount Marshall
#
# [505 rows x 7 columns]

# %%
#define function to Geocode LGAs using Google Maps Geocode API
#length of API response is used as a criteria to identify bad requests, e.g. for non-existent addresses.

def get_coord(lga_name):

    url = r'https://maps.googleapis.com/maps/api/geocode/json?address='+lga_name+'+Australia&key='+api_key
    response = requests.get(url)
    if len(response.content) > 100:
        json_data = pd.read_json(response.content, orient='columns')
        api_resp=pd.io.json.json_normalize(json_data.results)
        api_resp.columns = api_resp.columns.str.replace('\.+', '_')
        temp = pd.DataFrame(api_resp)
        return [temp.geometry_location_lat[0], temp.geometry_location_lng[0], temp.formatted_address[0]]
    else: 
        return 'Bad_address'

# %%
#Iterate through the list of LGAs and for each LGA define Lat, Lng and formatted address

row_counter=0

for row in lga.itertuples():
    geocode_api_resp = get_coord(row.LGA)
    if geocode_api_resp != 'Bad_address':
        lga.at[row_counter, 'Lat'] = geocode_api_resp[0]
        lga.at[row_counter, 'Lng'] = geocode_api_resp[1]
        lga.at[row_counter, 'Formatted_address'] = geocode_api_resp[2]
    else:
        lga.at[row_counter, 'Lat'] = geocode_api_resp
        lga.at[row_counter, 'Lng'] = geocode_api_resp
        lga.at[row_counter, 'Formatted_address'] = geocode_api_resp
    row_counter += 1

# %%
lga
# Out:
#          Local_Government_Area  Humanitarian  Family  Skilled  Grand_Total  \
# 0                 Not Recorded           346   12991    17719        31056
# 1                 Brisbane (C)           963    4522     8748        14233
# 2                Fairfield (C)          4759    1569      323         6651
# 3               Parramatta (C)           389    1502     3577         5468
# 4                Melbourne (C)            60     896     4364         5320
# 5                   Sydney (C)            27    1377     3899         5303
# 6                     Hume (C)          2415     782     1225         4422
# 7                  Wyndham (C)           494    1358     2501         4353
# 8        Greater Dandenong (C)           441    1806     2056         4303
# 9           Unincorporated ACT           347    1241     2586         4174
# 10               Blacktown (C)           426    1478     2228         4132
# 11                  Monash (C)            38     927     2865         3830
# 12              Gold Coast (C)           101    1684     1941         3726
# 13                Stirling (C)           470    1139     1967         3576
# 14              Canterbury (C)           170    1294     1920         3384
# 15                   Casey (C)           456    1516     1408         3380
# 16                Moreland (C)           276     774     2197         3247
# 17              Whitehorse (C)            89     907     2192         3188
# 18               Liverpool (C)          1439    1055      579         3073
# 19              Whittlesea (C)           309    1009     1745         3063
# 20                 Canning (C)           259     849     1904         3012
# 21                  Auburn (C)           189    1029     1747         2965
# 22                    Ryde (C)            96     857     1980         2933
# 23                Rockdale (C)            18     790     2053         2861
# 24                 Holroyd (C)           225     800     1810         2835
# 25                Randwick (C)            51     645     2079         2775
# 26                Brimbank (C)           434    1060     1265         2759
# 27              Hurstville (C)            17     926     1783         2726
# 28               Glen Eira (C)             5     572     1973         2550
# 29               Bankstown (C)           338    1282      888         2508
# ..                         ...           ...     ...      ...          ...
# 475            Boyup Brook (S)             0       0        0            0
# 476              Cranbrook (S)             0       0        0            0
# 477             Mukinbudin (S)             0       0        0            0
# 478              Perenjori (S)             0       0        0            0
# 479                   Kent (S)             0       0        0            0
# 480  Lower Eyre Peninsula (DC)             0       0        0            0
# 481                Mullewa (S)             0       0        0            0
# 482                 Morawa (S)             0       0        0            0
# 483                Bombala (A)             0       0        0            0
# 484                 Bulloo (S)             0       0        0            0
# 485             Tumby Bay (DC)             0       0        0            0
# 486                 Barcoo (S)             0       0        0            0
# 487                 Dorset (M)             0       0        0            0
# 488                 Coorow (S)             0       0        0            0
# 489               Wickepin (S)             0       0        0            0
# 490                 Cleve (DC)             0       0        0            0
# 491               Pingelly (S)             0       0        0            0
# 492          Barunga West (DC)             0       0        0            0
# 493  Karoonda East Murray (DC)             0       0        0            0
# 494               Nungarin (S)             0       0        0            0
# 495               McKinlay (S)             0       0        0            0
# 496               Richmond (S)             0       0        0            0
# 497          Peterborough (DC)             0       0        0            0
# 498             Bruce Rock (S)             0       0        0            0
# 499             Tumbarumba (A)             0       0        0            0
# 500                 Boulia (S)             0       0        0            0
# 501                Dowerin (S)             0       0        0            0
# 502            Wyalkatchem (S)             0       0        0            0
# 503                 Wiluna (S)             0       0        0            0
# 504         Mount Marshall (S)             0       0        0            0
#
#      %_of_Total                   LGA          Lat          Lng  \
# 0      0.118457          Not Recorded  Bad_address  Bad_address
# 1      0.054289              Brisbane     -27.4698      153.025
# 2      0.025369             Fairfield     -33.8703      150.956
# 3      0.020857            Parramatta      -33.815      151.001
# 4      0.020292             Melbourne     -37.8136      144.963
# 5      0.020227                Sydney     -33.8688      151.209
# 6      0.016867                  Hume      -35.387       149.17
# 7      0.016604               Wyndham     -15.4825      128.123
# 8      0.016413     Greater Dandenong     -38.0061      145.204
# 9      0.015921                   ACT     -35.4735      149.012
# 10     0.015761             Blacktown      -33.771      150.906
# 11     0.014609                Monash     -37.9105      145.136
# 12     0.014212            Gold Coast     -28.0167        153.4
# 13     0.013640              Stirling      -31.883       115.81
# 14     0.012908            Canterbury     -33.9126      151.118
# 15     0.012892                 Casey     -38.1105      145.292
# 16     0.012385              Moreland     -37.7241       144.95
# 17     0.012160            Whitehorse     -37.8286      145.149
# 18     0.011721             Liverpool     -33.9209      150.923
# 19     0.011683            Whittlesea     -37.5139      145.114
# 20     0.011489               Canning     -32.0396      115.911
# 21     0.011309                Auburn     -33.8656      151.024
# 22     0.011187                  Ryde     -33.8153      151.101
# 23     0.010913              Rockdale     -33.9533       151.14
# 24     0.010814               Holroyd     -33.8372      150.966
# 25     0.010585              Randwick     -33.9164      151.237
# 26     0.010524              Brimbank     -37.7595      144.807
# 27     0.010398            Hurstville     -33.9667        151.1
# 28     0.009727             Glen Eira     -37.9035      145.038
# 29     0.009566             Bankstown     -33.9182      151.035
# ..          ...                   ...          ...          ...
# 475    0.000000           Boyup Brook      -33.834      116.388
# 476    0.000000             Cranbrook     -34.2972      117.552
# 477    0.000000            Mukinbudin     -30.9092      118.252
# 478    0.000000             Perenjori     -29.4652      116.485
# 479    0.000000                  Kent     -33.5439       118.86
# 480    0.000000  Lower Eyre Peninsula     -34.4458      135.525
# 481    0.000000               Mullewa     -28.5369      115.512
# 482    0.000000                Morawa     -29.2111      116.009
# 483    0.000000               Bombala     -36.9115      149.242
# 484    0.000000                Bulloo     -27.8167      142.022
# 485    0.000000             Tumby Bay     -34.3779      136.099
# 486    0.000000                Barcoo     -25.0312      142.361
# 487    0.000000                Dorset     -41.0312       147.72
# 488    0.000000                Coorow     -29.8835      116.023
# 489    0.000000              Wickepin     -32.7833        117.5
# 490    0.000000                 Cleve     -33.7029      136.496
# 491    0.000000              Pingelly      -32.534      117.086
# 492    0.000000          Barunga West     -33.7872      138.001
# 493    0.000000  Karoonda East Murray     -34.9322      140.101
# 494    0.000000              Nungarin      -31.187      118.101
# 495    0.000000              McKinlay     -21.2717      141.289
# 496    0.000000              Richmond      -37.823      144.998
# 497    0.000000          Peterborough     -32.9742      138.834
# 498    0.000000            Bruce Rock      -31.881      118.148
# 499    0.000000            Tumbarumba     -35.7695      148.006
# 500    0.000000                Boulia     -22.9113       139.91
# 501    0.000000               Dowerin     -31.1962      117.033
# 502    0.000000           Wyalkatchem     -31.1615      117.332
# 503    0.000000                Wiluna      -26.595      120.225
# 504    0.000000        Mount Marshall     -30.1549      118.019
#
#                              Formatted_address
# 0                                  Bad_address
# 1                      Brisbane QLD, Australia
# 2                Fairfield NSW 2165, Australia
# 3               Parramatta NSW 2150, Australia
# 4                     Melbourne VIC, Australia
# 5                        Sydney NSW, Australia
# 6                     Hume ACT 2620, Australia
# 7                   Wyndham WA 6740, Australia
# 8            Greater Dandenong, VIC, Australia
# 9      Australian Capital Territory, Australia
# 10               Blacktown NSW 2148, Australia
# 11    Scenic Blvd, Clayton VIC 3800, Australia
# 12                   Gold Coast QLD, Australia
# 13                 Stirling WA 6021, Australia
# 14              Canterbury NSW 2193, Australia
# 15                       Casey, VIC, Australia
# 16                    Moreland, VIC, Australia
# 17                  Whitehorse, VIC, Australia
# 18               Liverpool NSW 2170, Australia
# 19              Whittlesea VIC 3757, Australia
# 20                      Canning, WA, Australia
# 21                  Auburn NSW 2144, Australia
# 22                    Ryde NSW 2112, Australia
# 23                Rockdale NSW 2216, Australia
# 24                     Holroyd, NSW, Australia
# 25                Randwick NSW 2031, Australia
# 26                    Brimbank, VIC, Australia
# 27              Hurstville NSW 2220, Australia
# 28                   Glen Eira, VIC, Australia
# 29               Bankstown NSW 2200, Australia
# ..                                         ...
# 475             Boyup Brook WA 6244, Australia
# 476               Cranbrook WA 6321, Australia
# 477              Mukinbudin WA 6479, Australia
# 478               Perenjori WA 6620, Australia
# 479                        Kent, WA, Australia
# 480  DC of Lower Eyre Peninsula, SA, Australia
# 481                 Mullewa WA 6630, Australia
# 482                  Morawa WA 6623, Australia
# 483                Bombala NSW 2632, Australia
# 484                     Bulloo, QLD, Australia
# 485               Tumby Bay SA 5605, Australia
# 486                     Barcoo, QLD, Australia
# 487                     Dorset, TAS, Australia
# 488                  Coorow WA 6515, Australia
# 489                Wickepin WA 6370, Australia
# 490                   Cleve SA 5640, Australia
# 491                Pingelly WA 6308, Australia
# 492          DC of Barunga West, SA, Australia
# 493  DC of Karoonda East Murray, SA, Australia
# 494                Nungarin WA 6490, Australia
# 495               Mckinlay QLD 4823, Australia
# 496               Richmond VIC 3121, Australia
# 497            Peterborough SA 5422, Australia
# 498              Bruce Rock WA 6418, Australia
# 499             Tumbarumba NSW 2653, Australia
# 500                 Boulia QLD 4829, Australia
# 501                 Dowerin WA 6461, Australia
# 502             Wyalkatchem WA 6485, Australia
# 503                  Wiluna WA 6646, Australia
# 504              Mount Marshall, WA, Australia
#
# [505 rows x 10 columns]

# %%
lga.to_csv('/Users/alexanderfetisov/Documents/personal/lga_2016.csv') #write results into csv
