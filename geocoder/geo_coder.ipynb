# %% [markdown]
# ### This notebook perfoms the following tasks:
# ##### 1) read Historical-Settlement-Reports excel file from DATA.GOV.AU
# ##### 2) ingest a selected report(sheet) into pandas dataframe
# ##### 3) GeoCode LGA with lat,long using Google Maps Geocoding API. Note you will need to use your own Google API key; the code performance depends on whether you use free test API key or commercial one.
# ##### 4) Visualise the results

# %%
import pandas as pd
import re
import requests

# %%
#Google Maps Geocoding API key. 
#Please request one from https://developers.google.com/maps/documentation/geocoding/start

api_key = 'AIzaSyBVN5lt3AWWVN7dnoZse38ymLuS3pjM8p4'

# %%
file='https://data.gov.au/dataset/8d1b90a9-a4d7-4b10-ad6a-8273722c8628/resource/bea8a0d4-4d63-42bf-9325-ac1cd0d50009/download/settlement-data-reports-january-2017-to-30-september-2017.xlsx'

# %%
#read the file into dataframe
report = pd.ExcelFile(file)

# %%
#define a function to enumerate all elements of a list
def list_all_elements_of_a_list(list_name):
    for i in range (0,len(list_name)):
        print(i,":",list_name[i])

# %%
#list all sheets of the excel file
list_all_elements_of_a_list(report.sheet_names)
# Out:
# 0 : Current States
# 1 : Age Group
# 2 : Country of Birth
# 3 : Ethnicity
# 4 : Gender
# 5 : Local Government Area
# 6 : Main Language
# 7 : Religion
# 8 : Caveats
# 9 : Settlement Date

# %%
# read a specific sheet to DataFrame. We are interested in "Local Government Area" sheet.
sheet_id = 5

#skip the first 11 rows in the Excel sheet
skip_rows = 11 

#skip the first 11 rows in the Excel sheet
read_columns = [0,1,2,3,4,5]

# %%
#ingest sheet into dataframe
lga = report.parse(report.sheet_names[sheet_id], skiprows=skip_rows, usecols=read_columns, skip_footer=1)

# %%
#replace spaces in columns' header with _
lga.columns = lga.columns.str.replace('\s+', '_')

# %%
#Extract exact suburb name. Also convert 'Unincorporated <state>' into <state>.

def get_state(lga_name):
    state_name =  re.search('^.*(?=(\s\())', lga_name)
    unincorp_name =  re.search('Unincorporated', lga_name)
    
    # If state_name exists, extract and return it.
    if state_name:
        return state_name.group()
    # If lga_name conctains "Unicorporated", extract and return only State name.
    elif unincorp_name:
        return re.search('[^ ]* (.*)', lga_name).group(1)
    # in all other cases return original value
    else:
        return lga_name

# %%
lga['LGA'] = lga['Local_Government_Area'].apply(get_state)

# %%
lga
# Out:
#         Local_Government_Area  Humanitarian  Family  Skilled  Grand_Total  \
# 0                Not Recorded           174    9082    13219        22475
# 1                Brisbane (C)           469    3372     7256        11098
# 2               Melbourne (C)            53     784     4058         4895
# 3              Parramatta (C)           288    1097     3094         4479
# 4                  Sydney (C)            15    1142     3311         4468
# 5               Fairfield (C)          2425    1224      270         3919
# 6                 Wyndham (C)           291    1037     2242         3570
# 7          Unincorporated ACT           164     933     2135         3232
# 8               Blacktown (C)           353    1110     1739         3202
# 9              Gold Coast (C)            64    1319     1713         3096
# 10      Greater Dandenong (C)           276    1250     1556         3082
# 11                   Hume (C)          1418     576     1064         3058
# 12                 Monash (C)            25     622     2356         3003
# 13                  Casey (C)           343    1247     1067         2657
# 14             Whittlesea (C)           248     786     1528         2562
# 15             Canterbury (C)           136     976     1410         2522
# 16               Moreland (C)           116     570     1801         2487
# 17             Whitehorse (C)            27     650     1707         2384
# 18                 Auburn (C)           120     842     1420         2382
# 19                Holroyd (C)           187     552     1588         2327
# 20              Liverpool (C)           936     851      535         2322
# 21               Stirling (C)           181     794     1308         2283
# 22                   Ryde (C)            41     645     1551         2237
# 23               Rockdale (C)            22     612     1595         2229
# 24               Randwick (C)            18     524     1655         2197
# 25               Brimbank (C)           284     735     1138         2157
# 26              Glen Eira (C)             0     450     1577         2029
# 27             Hurstville (C)            16     661     1342         2019
# 28                Canning (C)           121     563     1298         1982
# 29             Boroondara (C)            15     432     1391         1838
# ..                        ...           ...     ...      ...          ...
# 477            Jerilderie (A)             0       0        0            0
# 478                Barcoo (S)             0       0        0            0
# 479          Queenscliffe (B)             0       0        0            0
# 480            Diamantina (S)             0       0        0            0
# 481        Upper Gascoyne (S)             0       0        0            0
# 482                Cleve (DC)             0       0        0            0
# 483              Pingelly (S)             0       0        0            0
# 484  Broomehill-Tambellup (S)             0       0        0            0
# 485   Upper Lachlan Shire (A)             0       0        0            0
# 486               Boorowa (A)             0       0        0            0
# 487      Flinders Ranges (DC)             0       0        0            0
# 488              Mingenew (S)             0       0        0            0
# 489          Kellerberrin (S)             0       0        0            0
# 490          Woodanilling (S)             0       0        0            0
# 491              McKinlay (S)             0       0        0            0
# 492              Wudinna (DC)             0       0        0            0
# 493                Coorow (S)             0       0        0            0
# 494            Mukinbudin (S)             0       0        0            0
# 495                 Kulin (S)             0       0        0            0
# 496     Franklin Harbour (DC)             0       0        0            0
# 497              Williams (S)             0       0        0            0
# 498            Tumbarumba (A)             0       0        0            0
# 499                Boulia (S)             0       0        0            0
# 500           Boyup Brook (S)             0       0        0            0
# 501            Dumbleyung (S)             0       0        0            0
# 502                   Hay (A)             0       0        0            0
# 503                Morawa (S)             0       0        0            0
# 504        Unincorporated NSW             0       0        0            0
# 505                Dungog (A)             0       0        0            0
# 506                Wakool (A)             0       0        0            0
#
#       %_Total                   LGA
# 0    0.113593          Not Recorded
# 1    0.056092              Brisbane
# 2    0.024740             Melbourne
# 3    0.022638            Parramatta
# 4    0.022582                Sydney
# 5    0.019807             Fairfield
# 6    0.018044               Wyndham
# 7    0.016335                   ACT
# 8    0.016184             Blacktown
# 9    0.015648            Gold Coast
# 10   0.015577     Greater Dandenong
# 11   0.015456                  Hume
# 12   0.015178                Monash
# 13   0.013429                 Casey
# 14   0.012949            Whittlesea
# 15   0.012747            Canterbury
# 16   0.012570              Moreland
# 17   0.012049            Whitehorse
# 18   0.012039                Auburn
# 19   0.011761               Holroyd
# 20   0.011736             Liverpool
# 21   0.011539              Stirling
# 22   0.011306                  Ryde
# 23   0.011266              Rockdale
# 24   0.011104              Randwick
# 25   0.010902              Brimbank
# 26   0.010255             Glen Eira
# 27   0.010204            Hurstville
# 28   0.010017               Canning
# 29   0.009290            Boroondara
# ..        ...                   ...
# 477  0.000000            Jerilderie
# 478  0.000000                Barcoo
# 479  0.000000          Queenscliffe
# 480  0.000000            Diamantina
# 481  0.000000        Upper Gascoyne
# 482  0.000000                 Cleve
# 483  0.000000              Pingelly
# 484  0.000000  Broomehill-Tambellup
# 485  0.000000   Upper Lachlan Shire
# 486  0.000000               Boorowa
# 487  0.000000       Flinders Ranges
# 488  0.000000              Mingenew
# 489  0.000000          Kellerberrin
# 490  0.000000          Woodanilling
# 491  0.000000              McKinlay
# 492  0.000000               Wudinna
# 493  0.000000                Coorow
# 494  0.000000            Mukinbudin
# 495  0.000000                 Kulin
# 496  0.000000      Franklin Harbour
# 497  0.000000              Williams
# 498  0.000000            Tumbarumba
# 499  0.000000                Boulia
# 500  0.000000           Boyup Brook
# 501  0.000000            Dumbleyung
# 502  0.000000                   Hay
# 503  0.000000                Morawa
# 504  0.000000                   NSW
# 505  0.000000                Dungog
# 506  0.000000                Wakool
#
# [507 rows x 7 columns]

# %%
#define function to Geocode suburbs using Google Maps Geocode API
#lenth of API response is used as a criteria to identify bad requests, e.g. for non-existent addresses.

def get_coord(lga_name):

    url = r'https://maps.googleapis.com/maps/api/geocode/json?address='+lga_name+'+Australia&key='+api_key
    response = requests.get(url)
    if len(response.content) > 100:
        json_data = pd.read_json(response.content, orient='columns')
        api_resp=pd.io.json.json_normalize(json_data.results)
        api_resp.columns = api_resp.columns.str.replace('\.+', '_')
        temp = pd.DataFrame(api_resp)
        return [temp.geometry_location_lat[0], temp.geometry_location_lng[0], temp.formatted_address[0]]
    else: 
        return 'Bad_address'

# %%
#Iterate through the list of LGAs and for each LGA define Lat, Lng and formatted address

row_counter=0

for row in lga.itertuples():
    geocode_api_resp = get_coord(row.LGA)
    if geocode_api_resp != 'Bad_address':
        lga.at[row_counter, 'Lat'] = geocode_api_resp[0]
        lga.at[row_counter, 'Lng'] = geocode_api_resp[1]
        lga.at[row_counter, 'Formatted_address'] = geocode_api_resp[2]
    else:
        lga.at[row_counter, 'Lat'] = geocode_api_resp
        lga.at[row_counter, 'Lng'] = geocode_api_resp
        lga.at[row_counter, 'Formatted_address'] = geocode_api_resp
    row_counter += 1

# %%
lga
# Out:
#         Local_Government_Area  Humanitarian  Family  Skilled  Grand_Total  \
# 0                Not Recorded           174    9082    13219        22475
# 1                Brisbane (C)           469    3372     7256        11098
# 2               Melbourne (C)            53     784     4058         4895
# 3              Parramatta (C)           288    1097     3094         4479
# 4                  Sydney (C)            15    1142     3311         4468
# 5               Fairfield (C)          2425    1224      270         3919
# 6                 Wyndham (C)           291    1037     2242         3570
# 7          Unincorporated ACT           164     933     2135         3232
# 8               Blacktown (C)           353    1110     1739         3202
# 9              Gold Coast (C)            64    1319     1713         3096
# 10      Greater Dandenong (C)           276    1250     1556         3082
# 11                   Hume (C)          1418     576     1064         3058
# 12                 Monash (C)            25     622     2356         3003
# 13                  Casey (C)           343    1247     1067         2657
# 14             Whittlesea (C)           248     786     1528         2562
# 15             Canterbury (C)           136     976     1410         2522
# 16               Moreland (C)           116     570     1801         2487
# 17             Whitehorse (C)            27     650     1707         2384
# 18                 Auburn (C)           120     842     1420         2382
# 19                Holroyd (C)           187     552     1588         2327
# 20              Liverpool (C)           936     851      535         2322
# 21               Stirling (C)           181     794     1308         2283
# 22                   Ryde (C)            41     645     1551         2237
# 23               Rockdale (C)            22     612     1595         2229
# 24               Randwick (C)            18     524     1655         2197
# 25               Brimbank (C)           284     735     1138         2157
# 26              Glen Eira (C)             0     450     1577         2029
# 27             Hurstville (C)            16     661     1342         2019
# 28                Canning (C)           121     563     1298         1982
# 29             Boroondara (C)            15     432     1391         1838
# ..                        ...           ...     ...      ...          ...
# 477            Jerilderie (A)             0       0        0            0
# 478                Barcoo (S)             0       0        0            0
# 479          Queenscliffe (B)             0       0        0            0
# 480            Diamantina (S)             0       0        0            0
# 481        Upper Gascoyne (S)             0       0        0            0
# 482                Cleve (DC)             0       0        0            0
# 483              Pingelly (S)             0       0        0            0
# 484  Broomehill-Tambellup (S)             0       0        0            0
# 485   Upper Lachlan Shire (A)             0       0        0            0
# 486               Boorowa (A)             0       0        0            0
# 487      Flinders Ranges (DC)             0       0        0            0
# 488              Mingenew (S)             0       0        0            0
# 489          Kellerberrin (S)             0       0        0            0
# 490          Woodanilling (S)             0       0        0            0
# 491              McKinlay (S)             0       0        0            0
# 492              Wudinna (DC)             0       0        0            0
# 493                Coorow (S)             0       0        0            0
# 494            Mukinbudin (S)             0       0        0            0
# 495                 Kulin (S)             0       0        0            0
# 496     Franklin Harbour (DC)             0       0        0            0
# 497              Williams (S)             0       0        0            0
# 498            Tumbarumba (A)             0       0        0            0
# 499                Boulia (S)             0       0        0            0
# 500           Boyup Brook (S)             0       0        0            0
# 501            Dumbleyung (S)             0       0        0            0
# 502                   Hay (A)             0       0        0            0
# 503                Morawa (S)             0       0        0            0
# 504        Unincorporated NSW             0       0        0            0
# 505                Dungog (A)             0       0        0            0
# 506                Wakool (A)             0       0        0            0
#
#       %_Total                   LGA          Lat          Lng  \
# 0    0.113593          Not Recorded  Bad_address  Bad_address
# 1    0.056092              Brisbane     -27.4698      153.025
# 2    0.024740             Melbourne     -37.8136      144.963
# 3    0.022638            Parramatta      -33.815      151.001
# 4    0.022582                Sydney     -33.8688      151.209
# 5    0.019807             Fairfield     -33.8703      150.956
# 6    0.018044               Wyndham     -15.4825      128.123
# 7    0.016335                   ACT     -35.4735      149.012
# 8    0.016184             Blacktown      -33.771      150.906
# 9    0.015648            Gold Coast     -28.0167        153.4
# 10   0.015577     Greater Dandenong     -38.0061      145.204
# 11   0.015456                  Hume      -35.387       149.17
# 12   0.015178                Monash     -37.9105      145.136
# 13   0.013429                 Casey     -38.1105      145.292
# 14   0.012949            Whittlesea     -37.5139      145.114
# 15   0.012747            Canterbury     -33.9126      151.118
# 16   0.012570              Moreland     -37.7241       144.95
# 17   0.012049            Whitehorse     -37.8286      145.149
# 18   0.012039                Auburn     -33.8656      151.024
# 19   0.011761               Holroyd     -33.8372      150.966
# 20   0.011736             Liverpool     -33.9209      150.923
# 21   0.011539              Stirling      -31.883       115.81
# 22   0.011306                  Ryde     -33.8153      151.101
# 23   0.011266              Rockdale     -33.9533       151.14
# 24   0.011104              Randwick     -33.9164      151.237
# 25   0.010902              Brimbank     -37.7595      144.807
# 26   0.010255             Glen Eira     -37.9035      145.038
# 27   0.010204            Hurstville     -33.9667        151.1
# 28   0.010017               Canning     -32.0396      115.911
# 29   0.009290            Boroondara     -37.8119      145.071
# ..        ...                   ...          ...          ...
# 477  0.000000            Jerilderie     -35.3524      145.738
# 478  0.000000                Barcoo     -25.0312      142.361
# 479  0.000000          Queenscliffe     -38.2678      144.629
# 480  0.000000            Diamantina     -24.8426      139.691
# 481  0.000000        Upper Gascoyne     -24.4081      116.041
# 482  0.000000                 Cleve     -33.7029      136.496
# 483  0.000000              Pingelly      -32.534      117.086
# 484  0.000000  Broomehill-Tambellup     -33.9279      117.643
# 485  0.000000   Upper Lachlan Shire     -34.4586       149.38
# 486  0.000000               Boorowa     -34.4393      148.723
# 487  0.000000       Flinders Ranges     -31.4167       138.75
# 488  0.000000              Mingenew     -29.1939      115.441
# 489  0.000000          Kellerberrin       -31.63       117.71
# 490  0.000000          Woodanilling     -33.5632      117.422
# 491  0.000000              McKinlay     -21.2717      141.289
# 492  0.000000               Wudinna     -33.0475      135.462
# 493  0.000000                Coorow     -29.8835      116.023
# 494  0.000000            Mukinbudin     -30.9092      118.252
# 495  0.000000                 Kulin       -32.67       118.15
# 496  0.000000      Franklin Harbour     -33.4691      136.903
# 497  0.000000              Williams     -33.0333      116.883
# 498  0.000000            Tumbarumba     -35.7695      148.006
# 499  0.000000                Boulia     -22.9113       139.91
# 500  0.000000           Boyup Brook      -33.834      116.388
# 501  0.000000            Dumbleyung     -33.3109      117.752
# 502  0.000000                   Hay        -34.5       144.85
# 503  0.000000                Morawa     -29.2111      116.009
# 504  0.000000                   NSW     -31.2532      146.921
# 505  0.000000                Dungog     -32.4047      151.752
# 506  0.000000                Wakool      -35.469      144.389
#
#                                      Formatted_address
# 0                                          Bad_address
# 1                              Brisbane QLD, Australia
# 2                             Melbourne VIC, Australia
# 3                       Parramatta NSW 2150, Australia
# 4                                Sydney NSW, Australia
# 5                        Fairfield NSW 2165, Australia
# 6                           Wyndham WA 6740, Australia
# 7              Australian Capital Territory, Australia
# 8                        Blacktown NSW 2148, Australia
# 9                            Gold Coast QLD, Australia
# 10                   Greater Dandenong, VIC, Australia
# 11                            Hume ACT 2620, Australia
# 12            Scenic Blvd, Clayton VIC 3800, Australia
# 13                               Casey, VIC, Australia
# 14                      Whittlesea VIC 3757, Australia
# 15                      Canterbury NSW 2193, Australia
# 16                            Moreland, VIC, Australia
# 17                          Whitehorse, VIC, Australia
# 18                          Auburn NSW 2144, Australia
# 19                             Holroyd, NSW, Australia
# 20                       Liverpool NSW 2170, Australia
# 21                         Stirling WA 6021, Australia
# 22                            Ryde NSW 2112, Australia
# 23                        Rockdale NSW 2216, Australia
# 24                        Randwick NSW 2031, Australia
# 25                            Brimbank, VIC, Australia
# 26                           Glen Eira, VIC, Australia
# 27                      Hurstville NSW 2220, Australia
# 28                              Canning, WA, Australia
# 29                          Boroondara, VIC, Australia
# ..                                                 ...
# 477                     Jerilderie NSW 2716, Australia
# 478                             Barcoo, QLD, Australia
# 479                    Queenscliff VIC 3225, Australia
# 480                         Diamantina, QLD, Australia
# 481                 Upper Gascoyne, WA 6705, Australia
# 482                           Cleve SA 5640, Australia
# 483                        Pingelly WA 6308, Australia
# 484                Broomehill-Tambellup, WA, Australia
# 485                Upper Lachlan Shire, NSW, Australia
# 486                        Boorowa NSW 2586, Australia
# 487  Flinders Range, Flinders Ranges SA 5434, Austr...
# 488                        Mingenew WA 6522, Australia
# 489                    Kellerberrin WA 6410, Australia
# 490                    Woodanilling WA 6316, Australia
# 491                       Mckinlay QLD 4823, Australia
# 492                         Wudinna SA 5652, Australia
# 493                          Coorow WA 6515, Australia
# 494                      Mukinbudin WA 6479, Australia
# 495                           Kulin WA 6365, Australia
# 496         DC of Franklin Harbour, SA 5602, Australia
# 497                        Williams WA 6391, Australia
# 498                     Tumbarumba NSW 2653, Australia
# 499                         Boulia QLD 4829, Australia
# 500                     Boyup Brook WA 6244, Australia
# 501                      Dumbleyung WA 6350, Australia
# 502                            Hay NSW 2711, Australia
# 503                          Morawa WA 6623, Australia
# 504                         New South Wales, Australia
# 505                         Dungog NSW 2420, Australia
# 506                         Wakool NSW 2710, Australia
#
# [507 rows x 10 columns]

# %%
lga.to_csv('lga.csv') #write results into csv
